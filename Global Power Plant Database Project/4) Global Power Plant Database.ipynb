# %%
import pandas as pd        # for data manipulation
import numpy as np         # for mathematical calculations
import seaborn as sns      # for data visualization

import matplotlib.pyplot as plt  #for graphical analysis
# %matplotlib inline

from scipy.stats import zscore # to remove outliers

from sklearn.preprocessing import StandardScaler  # for normalize the model
from sklearn.preprocessing import LabelEncoder  # to convert object into int


from sklearn.model_selection import train_test_split  # for train and test model

import warnings                      # to ignore any warnings
warnings.filterwarnings("ignore")

from sklearn import metrics  # for model evaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report

# %%
data=pd.read_csv('database_IND.csv')  # read the data
data
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0    ...                    NaN                  NaN                 NaN
# 1    ...                    NaN                  NaN                 NaN
# 2    ...                    NaN                  NaN                 NaN
# 3    ...                 2019.0                  NaN          617.789264
# 4    ...                 2019.0                  NaN         3035.550000
# ..   ...                    ...                  ...                 ...
# 902  ...                 2019.0                  NaN                 NaN
# 903  ...                    NaN                  NaN                 NaN
# 904  ...                    NaN                  NaN                 NaN
# 905  ...                    NaN                  NaN                 NaN
# 906  ...                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3            843.747000          886.004428          663.774500
# 4           5916.370000         6243.000000         5385.579736
# ..                  ...                 ...                 ...
# 902            0.994875          233.596650          865.400000
# 903                 NaN                 NaN                 NaN
# 904                 NaN                 NaN                 NaN
# 905                 NaN                 NaN                 NaN
# 906                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [raw]
# As we see there are null/missing values are present in dataset & most of unnessasary columns are present so lets frist deal with it.

# %%
#first drop Unnamed: 0 column then remove duplicates & recheck the size
data=data.drop(columns=['country','country_long','name','latitude', 'longitude','owner','url','wepp_id','gppd_idnr','other_fuel2',
       'other_fuel3','generation_gwh_2013', 'generation_gwh_2019', 'estimated_generation_gwh','generation_data_source'],axis=1)

data.drop_duplicates(inplace=True)

print(data.shape)
# Out:
# (857, 12)

# %%
#understand data at high level check the stastics of dataset
data.describe(include='all')
# Out:
#         capacity_mw primary_fuel other_fuel1  commissioning_year  \
# count    857.000000          857         198          524.000000
# unique          NaN            8           3                 NaN
# top             NaN         Coal         Oil                 NaN
# freq            NaN          258         195                 NaN
# mean     344.050870          NaN         NaN         1997.091603
# std      602.268209          NaN         NaN           17.127662
# min        0.000000          NaN         NaN         1927.000000
# 25%       20.000000          NaN         NaN         1988.000000
# 50%       66.000000          NaN         NaN         2001.000000
# 75%      420.000000          NaN         NaN         2012.000000
# max     4760.000000          NaN         NaN         2018.000000
#
#                                source geolocation_source  \
# count                             857                839
# unique                            191                  3
# top     Central Electricity Authority                WRI
# freq                              516                729
# mean                              NaN                NaN
# std                               NaN                NaN
# min                               NaN                NaN
# 25%                               NaN                NaN
# 50%                               NaN                NaN
# 75%                               NaN                NaN
# max                               NaN                NaN
#
#         year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# count                   516.0           398.000000           422.000000
# unique                    NaN                  NaN                  NaN
# top                       NaN                  NaN                  NaN
# freq                      NaN                  NaN                  NaN
# mean                   2019.0          2431.823590          2428.226946
# std                       0.0          4026.440035          4194.596959
# min                    2019.0             0.000000             0.000000
# 25%                    2019.0           223.557672           176.381063
# 50%                    2019.0           801.123775           711.181225
# 75%                    2019.0          3035.306250          3084.121250
# max                    2019.0         28127.000000         30539.000000
#
#         generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# count            434.000000           440.000000           448.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean            2467.936859          2547.759305          2600.804099
# std             4162.884308          4196.991169          4314.880456
# min                0.000000             0.000000             0.000000
# 25%              188.285252           177.874930           193.378250
# 50%              737.205450           817.977250           751.644375
# 75%             3282.861313          3275.690475          3143.535900
# max            30015.000000         35116.000000         35136.000000

# %% [raw]
# Observations:
#     1) null vallues present
#     2) most of columns have missing values like other_fuel2	,other_fuel3, generation_gwh_2013, generation_gwh_2019, estimated_generation_gwh lets drop frist before dealing with null values.
#     3)we have categorical data type(object type)

# %%
# check the no. of rows & column & finding the count of missing value
print(data.isna().sum())

#printing the summary of data type
data.info()
# Out:
# capacity_mw                0
# primary_fuel               0
# other_fuel1              659
# commissioning_year       333
# source                     0
# geolocation_source        18
# year_of_capacity_data    341
# generation_gwh_2014      459
# generation_gwh_2015      435
# generation_gwh_2016      423
# generation_gwh_2017      417
# generation_gwh_2018      409
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 857 entries, 0 to 905
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   capacity_mw            857 non-null    float64
#  1   primary_fuel           857 non-null    object
#  2   other_fuel1            198 non-null    object
#  3   commissioning_year     524 non-null    float64
#  4   source                 857 non-null    object
#  5   geolocation_source     839 non-null    object
#  6   year_of_capacity_data  516 non-null    float64
#  7   generation_gwh_2014    398 non-null    float64
#  8   generation_gwh_2015    422 non-null    float64
#  9   generation_gwh_2016    434 non-null    float64
#  10  generation_gwh_2017    440 non-null    float64
#  11  generation_gwh_2018    448 non-null    float64
# dtypes: float64(8), object(4)
# memory usage: 87.0+ KB

# %%
# Remove null value as we can not fill capacity & fule type by mean mode method as its useless so lets drop the NAN
data=data.dropna()
print(data.shape)
data.head(5)
# Out:
# (168, 12)
#     capacity_mw primary_fuel other_fuel1  commissioning_year  \
# 4        1800.0         Coal         Oil              2015.0
# 5         250.0         Coal         Oil              2005.0
# 9         210.0         Coal         Oil              2008.0
# 10       1350.0         Coal         Oil              2014.0
# 12       1200.0         Coal         Oil              2011.0
#
#                            source geolocation_source  year_of_capacity_data  \
# 4   Central Electricity Authority                WRI                 2019.0
# 5   Central Electricity Authority                WRI                 2019.0
# 9   Central Electricity Authority                WRI                 2019.0
# 10  Central Electricity Authority                WRI                 2019.0
# 12  Central Electricity Authority                WRI                 2019.0
#
#     generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 4              3035.550            5916.3700            6243.0000
# 5              1153.421            1208.8520            1175.7650
# 9              1887.904            1643.0460            1338.0930
# 10             1920.971            5629.6630            1701.0080
# 12             7744.000            8076.8105            7902.0216
#
#     generation_gwh_2017  generation_gwh_2018
# 4           5385.579736             7279.000
# 5           1147.913000              976.655
# 9           1563.457000             1487.880
# 10          4350.558000             3717.154
# 12          7940.740000             7873.973

# %% [raw]
# now our data looks good ,lets move further for preproccesing  & distribution

# %%
data.describe(include='all')
# Out:
#         capacity_mw primary_fuel other_fuel1  commissioning_year  \
# count    168.000000          168         168          168.000000
# unique          NaN            3           3                 NaN
# top             NaN         Coal         Oil                 NaN
# freq            NaN          160         166                 NaN
# mean    1060.685089          NaN         NaN         2003.904762
# std      880.000525          NaN         NaN           11.130816
# min       35.000000          NaN         NaN         1966.000000
# 25%      490.000000          NaN         NaN         1996.000000
# 50%      920.000000          NaN         NaN         2009.000000
# 75%     1340.000000          NaN         NaN         2012.250000
# max     4760.000000          NaN         NaN         2017.000000
#
#                                source geolocation_source  \
# count                             168                168
# unique                              1                  1
# top     Central Electricity Authority                WRI
# freq                              168                168
# mean                              NaN                NaN
# std                               NaN                NaN
# min                               NaN                NaN
# 25%                               NaN                NaN
# 50%                               NaN                NaN
# 75%                               NaN                NaN
# max                               NaN                NaN
#
#         year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# count                   168.0           168.000000           168.000000
# unique                    NaN                  NaN                  NaN
# top                       NaN                  NaN                  NaN
# freq                      NaN                  NaN                  NaN
# mean                   2019.0          4577.371409          4894.690224
# std                       0.0          5315.190198          5631.588919
# min                    2019.0             0.000000             0.000000
# 25%                    2019.0          1040.711125          1333.724000
# 50%                    2019.0          3071.416000          3503.860500
# 75%                    2019.0          6166.850000          5992.332875
# max                    2019.0         28127.000000         30539.000000
#
#         generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# count            168.000000           168.000000           168.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean            4959.336545          5045.142661          5215.960018
# std             5609.097504          5648.606510          5864.148972
# min                0.000000             0.000000             0.000000
# 25%             1360.466423          1531.967500          1256.375000
# 50%             3384.205250          3558.992500          3293.532000
# 75%             6170.832500          6339.534675          6824.237500
# max            30015.000000         35116.000000         35136.000000

# %%
# lets seaprate the catogorical data & numirical data
numerics=['int8','int16','int32','int64','float16','float32','float64']
cat_col=[] #empty list
features=data.columns.values.tolist()
for i in features:
    if data[i].dtype in numerics:
        continue
    cat_col.append(i)
cat_col
# Out:
# ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']

# %% [raw]
# As our frist target is primary fule so for the prediction we will convert object in to int by using lable encoder and other_fuel1 by get dummies method

# %%
label = LabelEncoder()
df=label.fit_transform(data["primary_fuel"]) 
pd.Series(df)
data["primary_fuel"]=df

# %%
df=label.fit_transform(data["geolocation_source"]) 
pd.Series(df)
data["geolocation_source"]=df

# %%
df=label.fit_transform(data["source"]) 
pd.Series(df)
data["source"]=df

# %%
df_dummies=pd.get_dummies(data['other_fuel1'],drop_first=True)
print(df_dummies.head(2))
print(df_dummies.shape)
data=data.join(df_dummies) #join to orignal dataset
# Out:
#    Gas  Oil
# 4    0    1
# 5    0    1
# (168, 2)

# %%
data=data.drop(columns='other_fuel1',axis=1)

# %%
data.head(3)
# Out:
#    capacity_mw  primary_fuel  commissioning_year  source  geolocation_source  \
# 4       1800.0             0              2015.0       0                   0
# 5        250.0             0              2005.0       0                   0
# 9        210.0             0              2008.0       0                   0
#
#    year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# 4                 2019.0             3035.550             5916.370
# 5                 2019.0             1153.421             1208.852
# 9                 2019.0             1887.904             1643.046
#
#    generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  Gas  Oil
# 4             6243.000          5385.579736             7279.000    0    1
# 5             1175.765          1147.913000              976.655    0    1
# 9             1338.093          1563.457000             1487.880    0    1

# %%
#check multicolinearity
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,annot_kws={'size':10})
plt.show()

# %%
#lets see the distrubution 
plt.figure(figsize=(15,20))
plotnumber=1
for column in data:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [raw]
# we can see from above distribusion columns 'capacity_mw','generation_gwh_2014','generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017','generation_gwh_2018', 'Gas',are rightskwed data & other like 'oil','commissioning_year' are leftskwed data so lets remove frist skweness for data by using power transformation

# %%
from sklearn.preprocessing import PowerTransformer

fetures=['capacity_mw','generation_gwh_2014','generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017','generation_gwh_2018', 'Gas','Oil','commissioning_year']
pt=PowerTransformer()
data[fetures]=pt.fit_transform(data[fetures].values)

# %%
data[fetures]
# Out:
#      capacity_mw  generation_gwh_2014  generation_gwh_2015  \
# 4       0.976813             0.081528             0.547039
# 5      -1.120677            -0.524027            -0.606771
# 9      -1.253777            -0.238489            -0.427507
# 10      0.590480            -0.227604             0.501243
# 12      0.441484             0.869911             0.851413
# ..           ...                  ...                  ...
# 877    -0.518186             0.171646            -0.060848
# 880     2.552821             2.383031             2.481601
# 889     0.701460             0.739918             0.422952
# 890    -0.443376            -0.575734            -0.424482
# 899    -0.338173             0.118791             0.144396
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018       Gas  \
# 4               0.582767             0.425474             0.677195 -0.077382
# 5              -0.653821            -0.653606            -0.695002 -0.077382
# 9              -0.580167            -0.480231            -0.477318 -0.077382
# 10             -0.435003             0.241201             0.114351 -0.077382
# 12              0.817865             0.796510             0.751491 -0.077382
# ..                   ...                  ...                  ...       ...
# 877             0.043680            -0.086722            -0.051394 -0.077382
# 880             2.549522             2.760831             2.601930 -0.077382
# 889             0.085388             0.673218             0.715558 -0.077382
# 890            -0.628729            -0.725816            -0.713130 -0.077382
# 899            -0.012413            -0.012249            -0.031360 -0.077382
#
#           Oil  commissioning_year
# 4    0.109764            1.141055
# 5    0.109764           -0.019388
# 9    0.109764            0.301294
# 10   0.109764            1.012705
# 12   0.109764            0.644796
# ..        ...                 ...
# 877  0.109764            0.413183
# 880  0.109764           -0.318734
# 889  0.109764           -1.608518
# 890  0.109764            0.527664
# 899  0.109764            0.191940
#
# [168 rows x 9 columns]

# %%
data.head()
# Out:
#     capacity_mw  primary_fuel  commissioning_year  source  geolocation_source  \
# 4      0.976813             0            1.141055       0                   0
# 5     -1.120677             0           -0.019388       0                   0
# 9     -1.253777             0            0.301294       0                   0
# 10     0.590480             0            1.012705       0                   0
# 12     0.441484             0            0.644796       0                   0
#
#     year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# 4                  2019.0             0.081528             0.547039
# 5                  2019.0            -0.524027            -0.606771
# 9                  2019.0            -0.238489            -0.427507
# 10                 2019.0            -0.227604             0.501243
# 12                 2019.0             0.869911             0.851413
#
#     generation_gwh_2016  generation_gwh_2017  generation_gwh_2018       Gas  \
# 4              0.582767             0.425474             0.677195 -0.077382
# 5             -0.653821            -0.653606            -0.695002 -0.077382
# 9             -0.580167            -0.480231            -0.477318 -0.077382
# 10            -0.435003             0.241201             0.114351 -0.077382
# 12             0.817865             0.796510             0.751491 -0.077382
#
#          Oil
# 4   0.109764
# 5   0.109764
# 9   0.109764
# 10  0.109764
# 12  0.109764

# %%
#lets see the distrubution after transformation
plt.figure(figsize=(15,20))
plotnumber=1
for column in data:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize =(10, 6))
sns.boxplot(y ='generation_gwh_2015', x ='primary_fuel', data = data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2015'>

# %%
print(data['primary_fuel'].value_counts())
# Out:
# 0    160
# 1      7
# 2      1
# Name: primary_fuel, dtype: int64

# %%
#plot each class frequency
sns.countplot(x='primary_fuel',data=data)
plt.show()

# %%
# Let's Seperate the data 
x=data.drop(columns=['primary_fuel','source','geolocation_source', 'year_of_capacity_data'])
y=data['primary_fuel']

# %%
# see how featurs r related to lable(Graphical Univariate Analysis)
plt.figure(figsize=(15,20))
plotnumber=1
for column in x:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.scatterplot(y,x[column])
    plotnumber+=1
plt.show()

# %%
# data stadardization
scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
#Split data into train & test by using this new fetures
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=355)

# %% [markdown]
# # Build Model to predict primary fule

# %%
def print_score(model,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=model.predict(x_train)
        print("Train Report:",r2_score(y_train,y_pred))
    elif train==False:
        pred=model.predict(x_test)
        print("Test Report:",accuracy_score(y_test,pred))
        print("Classification Report:",classification_report(y_test,pred))
        print("Confusion Matrix:",confusion_matrix(y_test,pred))

# %%
#Below is a function to find the accuracy of each model on the basis of K-fold cross validation.
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold

def model_accuracy(model,X_train=x_train,y_train=y_train):
    accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv =5)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

# %%
#Model no.1
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()

dt.fit(x_train,y_train)

print_score(dt,x_train,x_test,y_train,y_test,train=True)
print_score(dt,x_train,x_test,y_train,y_test,train=False)
model_accuracy(dt)
# Out:
# Train Report: 1.0
# Test Report: 0.9411764705882353
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        49
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.94        51
#    macro avg       0.66      0.73      0.68        51
# weighted avg       0.95      0.94      0.95        51
#
# Confusion Matrix: [[47  2]
#  [ 1  1]]
# Accuracy: 89.78 %
# Standard Deviation: 3.32 %

# %%
# Model no.2
from sklearn.linear_model import LogisticRegression

LR= LogisticRegression()
LR.fit(x_train,y_train)

print_score(LR,x_train,x_test,y_train,y_test,train=True)
print_score(LR,x_train,x_test,y_train,y_test,train=False)
model_accuracy(LR)
# Out:
# Train Report: 0.4173306772908364
# Test Report: 0.9607843137254902
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        49
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        51
#    macro avg       0.48      0.50      0.49        51
# weighted avg       0.92      0.96      0.94        51
#
# Confusion Matrix: [[49  0]
#  [ 2  0]]
# Accuracy: 94.89 %
# Standard Deviation: 1.61 %

# %%
# Model no.3
from sklearn.ensemble import RandomForestClassifier

rand_clf= RandomForestClassifier()
rand_clf.fit(x_train,y_train)

print_score(rand_clf,x_train,x_test,y_train,y_test,train=True)
print_score(rand_clf,x_train,x_test,y_train,y_test,train=False)
model_accuracy(rand_clf)
# Out:
# Train Report: 1.0
# Test Report: 0.9607843137254902
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        49
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        51
#    macro avg       0.48      0.50      0.49        51
# weighted avg       0.92      0.96      0.94        51
#
# Confusion Matrix: [[49  0]
#  [ 2  0]]
# Accuracy: 94.89 %
# Standard Deviation: 1.61 %

# %%
# Model no.4
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)

print_score(svc,x_train,x_test,y_train,y_test,train=True)
print_score(svc,x_train,x_test,y_train,y_test,train=False)
model_accuracy(svc)
# Out:
# Train Report: 0.4173306772908364
# Test Report: 0.9607843137254902
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        49
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        51
#    macro avg       0.48      0.50      0.49        51
# weighted avg       0.92      0.96      0.94        51
#
# Confusion Matrix: [[49  0]
#  [ 2  0]]
# Accuracy: 94.89 %
# Standard Deviation: 1.61 %

# %%
#Model no.5
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()

knn.fit(x_train,y_train)

print_score(knn,x_train,x_test,y_train,y_test,train=True)
print_score(knn,x_train,x_test,y_train,y_test,train=False)
model_accuracy(knn)
# Out:
# Train Report: -0.048804780876494425
# Test Report: 0.9607843137254902
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        49
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        51
#    macro avg       0.48      0.50      0.49        51
# weighted avg       0.92      0.96      0.94        51
#
# Confusion Matrix: [[49  0]
#  [ 2  0]]
# Accuracy: 94.89 %
# Standard Deviation: 1.61 %

# %%
# Hyper tuning by using GridSearchCV

from sklearn.model_selection import GridSearchCV

para={'max_depth':[20,3,40,6,10],'random_state':[41,35,56,300],'n_estimators':[20,30,75,64,45],'criterion':['gini','entropy']}
grid=GridSearchCV(estimator=rand_clf, param_grid=para,cv=10)
grid.fit(x_train,y_train)

print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 20, 'n_estimators': 20, 'random_state': 56}

# %%
rand_clf= RandomForestClassifier(n_estimators=20, max_depth=20, criterion='gini',random_state=56)
rand_clf.fit(x_train,y_train)

print_score(rand_clf,x_train,x_test,y_train,y_test,train=True)
print_score(rand_clf,x_train,x_test,y_train,y_test,train=False)
model_accuracy(rand_clf)
# Out:
# Train Report: 1.0
# Test Report: 0.9607843137254902
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        49
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        51
#    macro avg       0.48      0.50      0.49        51
# weighted avg       0.92      0.96      0.94        51
#
# Confusion Matrix: [[49  0]
#  [ 2  0]]
# Accuracy: 94.89 %
# Standard Deviation: 1.61 %

# %%
# Hyper tuning by using RandomizedSearchCV With RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

para={'max_depth':[20,3,40,6,10],'random_state':[41,35,56,300],'n_estimators':[20,30,75,64,45],'criterion':['gini','entropy']}
rand=RandomizedSearchCV(estimator=rand_clf, cv=2,param_distributions=para)
rand.fit(x_train,y_train)

rand.best_params_
# Out:
# {'random_state': 41, 'n_estimators': 45, 'max_depth': 20, 'criterion': 'gini'}

# %%
rand_clf= RandomForestClassifier(n_estimators=45, max_depth=20, criterion='entropy',random_state=41)
rand_clf.fit(x_train,y_train)

print_score(rand_clf,x_train,x_test,y_train,y_test,train=True)
print_score(rand_clf,x_train,x_test,y_train,y_test,train=False)
model_accuracy(rand_clf)
# Out:
# Train Report: 1.0
# Test Report: 0.9607843137254902
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        49
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        51
#    macro avg       0.48      0.50      0.49        51
# weighted avg       0.92      0.96      0.94        51
#
# Confusion Matrix: [[49  0]
#  [ 2  0]]
# Accuracy: 94.89 %
# Standard Deviation: 1.61 %

# %% [markdown]
# # Looking at accuracy & confusion matrix i m selecting RandomForestClassifier with GridSearchCV  hypertune parameter by using Kfold cross validation method

# %%
#save model
import pickle
Filename='Global_power_Finalized_model.pickle'
pickle.dump(svc,open(Filename,'wb'))

# %% [markdown]
# # Capacity MW Prediction Models

# %%
# Let's Seperate the data 
x=data.drop(columns=['capacity_mw','source','geolocation_source','year_of_capacity_data'])
y=data['capacity_mw']

# %%
# see how featurs r related to lable(Graphical Univariate Analysis)
plt.figure(figsize=(15,20))
plotnumber=1
for column in x:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.scatterplot(y,x[column])
    plotnumber+=1
plt.show()

# %%
# data stadardization
scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
#Split data into train & test by using this new fetures
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=958)

# %%
def print_score1(model,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=model.predict(x_train)
        print("Train Report:",r2_score(y_train,y_pred))
    elif train==False:
        pred=model.predict(x_test)
        print("Test Report:",r2_score(y_test,pred))
        print("RMSE:",np.sqrt(mean_squared_error(y_test,pred)))
        print("MAE:",mean_absolute_error(y_test,pred))
        print("MSE:",mean_squared_error(y_test,pred))

# %%
#Below is a function to find the accuracy of each model on the basis of K-fold cross validation.

from sklearn.model_selection import cross_val_score
def model_accuracy1(model,X_train=x_train,y_train=y_train):
    accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv =2)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

# %%
# Model no.1
from sklearn.linear_model import LinearRegression, Lasso, LassoCV

lcv=LassoCV(alphas=None,max_iter=1000,normalize=True)
lcv.fit(x_train,y_train)
alpha=lcv.alpha_
print(alpha)
Lasso_reg=Lasso(alpha).fit(x_train,y_train)

print_score1(Lasso_reg,x_train,x_test,y_train,y_test,train=True)
print_score1(Lasso_reg,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(Lasso_reg)
# Out:
# 0.00495898346340803
# Train Report: 0.7718827290983201
# Test Report: 0.787070626691266
# RMSE: 0.4335427875957919
# MAE: 0.3499547492500928
# MSE: 0.18795934867632993
# Accuracy: 72.73 %
# Standard Deviation: 3.18 %

# %%
# Model no.2
from sklearn.ensemble import RandomForestRegressor

rand_regressor= RandomForestRegressor()
rand_regressor.fit(x_train,y_train)

print_score1(rand_regressor,x_train,x_test,y_train,y_test,train=True)
print_score1(rand_regressor,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(rand_regressor)
# Out:
# Train Report: 0.9679648526311689
# Test Report: 0.8870220837353984
# RMSE: 0.31579915091836686
# MAE: 0.22450109494202597
# MSE: 0.09972910372076145
# Accuracy: 75.84 %
# Standard Deviation: 1.69 %

# %%
# Model no.3
from xgboost import XGBRegressor

xgb=XGBRegressor()
xgb.fit(x_train,y_train)

print_score1(xgb,x_train,x_test,y_train,y_test,train=True)
print_score1(xgb,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(xgb)
# Out:
# Train Report: 0.9999988133279241
# Test Report: 0.8671249962473292
# RMSE: 0.34248047933576914
# MAE: 0.2501750752413834
# MSE: 0.1172928787260582
# Accuracy: 70.23 %
# Standard Deviation: 3.84 %

# %%
#Model no.4
from sklearn.ensemble import GradientBoostingRegressor

gbdt=GradientBoostingRegressor()

gbdt.fit(x_train,y_train)

print_score1(gbdt,x_train,x_test,y_train,y_test,train=True)
print_score1(gbdt,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(gbdt)
# Out:
# Train Report: 0.9868777187063521
# Test Report: 0.8702928700637744
# RMSE: 0.338373312263664
# MAE: 0.25039674971131426
# MSE: 0.11449649845228307
# Accuracy: 69.09 %
# Standard Deviation: 4.96 %

# %%
#Model no.5
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()

dt.fit(x_train,y_train)

print_score1(dt,x_train,x_test,y_train,y_test,train=True)
print_score1(dt,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(dt)
# Out:
# Train Report: 1.0
# Test Report: 0.7554308437978078
# RMSE: 0.4646383156720746
# MAE: 0.33337164979282563
# MSE: 0.21588876439058244
# Accuracy: 59.06 %
# Standard Deviation: 4.90 %

# %%
#Model no.6
from sklearn.ensemble import BaggingRegressor

bb=BaggingRegressor()

bb.fit(x_train,y_train)

print_score1(bb,x_train,x_test,y_train,y_test,train=True)
print_score1(bb,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(bb)
# Out:
# Train Report: 0.9545919174659147
# Test Report: 0.9025822558785057
# RMSE: 0.29324675297793057
# MAE: 0.22339094987736907
# MSE: 0.08599365813209943
# Accuracy: 75.19 %
# Standard Deviation: 1.37 %

# %%
# Hyper tuning by using GridSearchCV
from sklearn.model_selection import GridSearchCV

para={'max_depth':range(0,12,2),'learning_rate':[0.25,0.1,0.01],'n_estimators':[20,50,70]}
grid=GridSearchCV(estimator=xgb, param_grid=para,cv=2)
grid.fit(x_train,y_train)

grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}

# %%
xgb=XGBRegressor(learning_rate= 0.1, max_depth=2,n_estimators=50)
xgb.fit(x_train,y_train)

print_score1(xgb,x_train,x_test,y_train,y_test,train=True)
print_score1(xgb,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(xgb)
# Out:
# Train Report: 0.906871728841893
# Test Report: 0.8630303038086811
# RMSE: 0.3477174003205805
# MAE: 0.2683589532863987
# MSE: 0.12090739048570286
# Accuracy: 74.43 %
# Standard Deviation: 1.94 %

# %%
# Hyper tuning by using RandomizedSearchCV With Bagging
from sklearn.model_selection import RandomizedSearchCV

dt=DecisionTreeRegressor()
para={'n_estimators':range(0,100,4),'random_state':[40,60,20,30]}
rand=RandomizedSearchCV(estimator=bb, cv=2,param_distributions=para)
rand.fit(x_train,y_train)

rand.best_params_
# Out:
# {'random_state': 60, 'n_estimators': 16}

# %%
bb=BaggingRegressor(n_estimators=24, random_state=30)

bb.fit(x_train,y_train)

print_score1(bb,x_train,x_test,y_train,y_test,train=True)
print_score1(bb,x_train,x_test,y_train,y_test,train=False)
model_accuracy1(bb)
# Out:
# Train Report: 0.9629959509814386
# Test Report: 0.8989504120737348
# RMSE: 0.2986630192641029
# MAE: 0.22270878761248347
# MSE: 0.0891995990759499
# Accuracy: 75.38 %
# Standard Deviation: 1.32 %

# %% [markdown]
# # Looking at accuracy & MSE i m selecting BaggingRegressor with RandomizedSearchCV hypertune parameter by using Kfold cross validation method
